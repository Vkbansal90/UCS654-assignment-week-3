# %%
import numpy as np
import pandas as pd

df = pd.read_csv("/kaggle/input/dataseta2/data.csv", encoding="latin1")

df = df.dropna(subset=["no2"])
x = df["no2"].values.astype(float)

print(f"Total samples used: {len(x)}")


r = 102316085

ar = 0.05 * (r % 7)
br = 0.3 * (r % 5 + 1)

print(f"ar = {ar}")
print(f"br = {br}")

z = x + ar * np.sin(br * x)

mu = np.mean(z)
vari = np.mean((z - mu) ** 2)

lamda = 1 / (2 * vari)
c = np.sqrt(lamda / np.pi)

print(f"μ (mean) = {mu}")
print(f"λ (lambda) = {lamda}")
print(f"c (constant) = {c}")
# Out:
# /tmp/ipykernel_55/1619410469.py:4: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/kaggle/input/dataseta2/data.csv", encoding="latin1")
# Total samples used: 419509
# ar = 0.2
# br = 0.3
# μ (mean) = 25.80277171419891
# λ (lambda) = 0.0014601849203202159
# c (constant) = 0.02155901889684258
